# %%
import gvision.core as gv
import io

# %%
api_key_file = '/Users/robin/Documents/Google_API_key.json'
image_file = 'tests/images/test-image3.jpg'

# %%
api = gv.Vision(api_key_file)

# %%
with io.open(image_file, 'rb')as img_bytes:
    objects = api.object_localization(img_bytes.read())

# %%
objects
# Out:
# localized_object_annotations {
#   mid: "/m/07mhn"
#   name: "Pants"
#   score: 0.9225577116012573
#   bounding_poly {
#     normalized_vertices {
#       x: 0.479656845331192
#       y: 0.44639864563941956
#     }
#     normalized_vertices {
#       x: 0.5997406840324402
#       y: 0.44639864563941956
#     }
#     normalized_vertices {
#       x: 0.5997406840324402
#       y: 0.8019291758537292
#     }
#     normalized_vertices {
#       x: 0.479656845331192
#       y: 0.8019291758537292
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01bfm9"
#   name: "Shorts"
#   score: 0.9119724631309509
#   bounding_poly {
#     normalized_vertices {
#       x: 0.3308858573436737
#       y: 0.43053290247917175
#     }
#     normalized_vertices {
#       x: 0.4401510953903198
#       y: 0.43053290247917175
#     }
#     normalized_vertices {
#       x: 0.4401510953903198
#       y: 0.628141462802887
#     }
#     normalized_vertices {
#       x: 0.3308858573436737
#       y: 0.628141462802887
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/0bt9lr"
#   name: "Dog"
#   score: 0.8989588618278503
#   bounding_poly {
#     normalized_vertices {
#       x: 0.6729200482368469
#       y: 0.5543906092643738
#     }
#     normalized_vertices {
#       x: 0.8244217038154602
#       y: 0.5543906092643738
#     }
#     normalized_vertices {
#       x: 0.8244217038154602
#       y: 0.8391222357749939
#     }
#     normalized_vertices {
#       x: 0.6729200482368469
#       y: 0.8391222357749939
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/03bt1vf"
#   name: "Woman"
#   score: 0.864998459815979
#   bounding_poly {
#     normalized_vertices {
#       x: 0.4567222595214844
#       y: 0.16832959651947021
#     }
#     normalized_vertices {
#       x: 0.6269530653953552
#       y: 0.16832959651947021
#     }
#     normalized_vertices {
#       x: 0.6269530653953552
#       y: 0.8153927326202393
#     }
#     normalized_vertices {
#       x: 0.4567222595214844
#       y: 0.8153927326202393
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.8431859612464905
#   bounding_poly {
#     normalized_vertices {
#       x: 0.3103858530521393
#       y: 0.14809174835681915
#     }
#     normalized_vertices {
#       x: 0.460043340921402
#       y: 0.14809174835681915
#     }
#     normalized_vertices {
#       x: 0.460043340921402
#       y: 0.8130884766578674
#     }
#     normalized_vertices {
#       x: 0.3103858530521393
#       y: 0.8130884766578674
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.8168189525604248
#   bounding_poly {
#     normalized_vertices {
#       x: 0.46052002906799316
#       y: 0.23382847011089325
#     }
#     normalized_vertices {
#       x: 0.6212262511253357
#       y: 0.23382847011089325
#     }
#     normalized_vertices {
#       x: 0.6212262511253357
#       y: 0.6215713024139404
#     }
#     normalized_vertices {
#       x: 0.46052002906799316
#       y: 0.6215713024139404
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/03gx245"
#   name: "Top"
#   score: 0.7480685710906982
#   bounding_poly {
#     normalized_vertices {
#       x: 0.46375954151153564
#       y: 0.25831708312034607
#     }
#     normalized_vertices {
#       x: 0.6196263432502747
#       y: 0.25831708312034607
#     }
#     normalized_vertices {
#       x: 0.6196263432502747
#       y: 0.503254771232605
#     }
#     normalized_vertices {
#       x: 0.46375954151153564
#       y: 0.503254771232605
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/03gx245"
#   name: "Top"
#   score: 0.6955450177192688
#   bounding_poly {
#     normalized_vertices {
#       x: 0.3049212396144867
#       y: 0.217354416847229
#     }
#     normalized_vertices {
#       x: 0.46134045720100403
#       y: 0.217354416847229
#     }
#     normalized_vertices {
#       x: 0.46134045720100403
#       y: 0.4743421971797943
#     }
#     normalized_vertices {
#       x: 0.3049212396144867
#       y: 0.4743421971797943
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/047vlmn"
#   name: "Outerwear"
#   score: 0.6189150810241699
#   bounding_poly {
#     normalized_vertices {
#       x: 0.4595017433166504
#       y: 0.23702360689640045
#     }
#     normalized_vertices {
#       x: 0.620820939540863
#       y: 0.23702360689640045
#     }
#     normalized_vertices {
#       x: 0.620820939540863
#       y: 0.5091056823730469
#     }
#     normalized_vertices {
#       x: 0.4595017433166504
#       y: 0.5091056823730469
#     }
#   }
# }
